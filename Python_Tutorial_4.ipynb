# %% [markdown]
# # MatplotLib Tutorial
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# This line is important in Jupyter Notebook as whenever we want to display any 
# matplotlib graphs or daigram we have to write plt.show but when we use 
# %matplotlib inline we don't need to write plt.show

# %%
import numpy as np

# %%
# Simple Example

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
# Plotting using Matplotlib

# plt scatter

plt.scatter(x,y,c='b')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Graph in 2D')

# To save figure we can use
plt.savefig('Test.png')

# %% [markdown]
# # Plot

# %%
# plt plot - In this we will get lines

plt.plot(x,y)

# %%
y=x*x
plt.plot(x,y)

# %%
# plt.plot(x,y,'r--')
# plt.plot(x,y,'r*-')
# plt.plot(x,y,'ro')
plt.plot(x,y,'ro-')

# %%
plt.plot(x,y,'r*', linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
# Creating subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'b*-')
plt.subplot(2,2,3)
plt.plot(x,y,'go')
plt.subplot(2,2,4)
plt.plot(x,y,'y*--')

# %%
x = np.arange(1,11)
y = 3*x+5
plt.title("Matplotlib Demo")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve

x = np.arange(0, 4*np.pi, 0.1)
y = np.sin(x)

plt.title("Sine wave form")
plt.plot(x,y)
plt.show()

# %%
# Compute the x and y coordinates for points on sine and cosine ccurves

x = np.arange(0, 5*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x, y_sin, 'r--')
plt.title("Sine Curve")

plt.subplot(2,1,2)
plt.plot(x, y_cos, 'g--')
plt.title("Cosine Curve")

plt.subplots_adjust(hspace=0.6)
# wspace = horizontal subplots spacing
# hspace = vertical subplots spacing

plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Bar Plot

x = [2,8,10]
y = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x,y)
plt.bar(x2,y2, color='g')
plt.title('Bar Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %% [markdown]
# # Histograms

# %%
# Histograms - Helps us to find out w.r.t. the numbers what is the density/count
# that we can see on the y-axis. (In the x-axis we will have all the numbers)
# This will be w.r.t bins. (Default: 10 bins)

a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
# plt.hist(a, bins=20)
plt.title("Histogram")
plt.show()

# %% [markdown]
# # Box Plot

# %%
# Box Plot - Helps to find percentiles

data = [np.random.normal(0, std, 100) for std in range(1, 4)]
# np.random.normal means selecting a normal distribution
# (0, std, 100) - (lower value, standard deviation values, step size)
# Circles represents Outliers

# Rectangular Box Plot
plt.boxplot(data, vert=True, patch_artist=True);
# vert = Flase will show the box plot horizontally
# patch_artist = False will remove the blue color

# %%
data
# Out:
# [array([ 0.66734739, -0.86561131, -0.27719774,  0.85430602,  0.32874018,
#         -0.93202928, -0.03471635, -1.277661  , -0.18393179, -0.25417726,
#          1.67384611, -0.08341673,  0.04335233, -0.56304037,  0.65460575,
#         -2.59968252,  0.67433631,  0.93944521,  2.17645732, -0.01703168,
#          2.78158635, -0.26649872, -0.13992753,  0.07034397,  0.39612138,
#          0.13777387,  0.02044088, -0.51407401,  1.55868494, -0.10949473,
#         -0.85477068, -0.29434288,  0.11716068, -1.60805132, -1.82154595,
#          1.46279732,  1.63289773, -0.86039219,  1.54649656,  0.00722521,
#          1.4178228 , -2.0165738 , -1.61118689,  0.8810371 ,  0.35952815,
#          0.61015901, -0.1175312 , -0.84753044,  0.75962029,  1.17169372,
#          1.29985285,  0.25211526,  0.54955743,  0.8562685 ,  3.43945315,
#         -0.87797501,  1.66946419,  0.50083281,  0.86922873, -1.2105469 ,
#          0.72406976, -0.60103518,  0.58161537, -0.36845527,  0.59869215,
# ...

# %% [markdown]
# # Pie Chart
